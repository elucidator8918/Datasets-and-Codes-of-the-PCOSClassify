# %% [markdown]
# ### Installing & Importing all the necessary packages
#
# Update system packages, install `libgl1`, and install the `openpyxl` library for handling Excel files
#
# - **`albumentations`**: Library for image augmentation to enhance training data diversity.
# - **`sweetviz`**: Generates high-density visualizations of pandas DataFrames for quick data analysis.
# - **`grad-cam`**: Visualizes important image regions for CNN predictions using Grad-CAM.
# - **`lime`**: Provides local explanations for machine learning model predictions.
# - **`pandas_profiling`**: Creates detailed reports of pandas DataFrames for exploratory data analysis.
# - **`shap`**: Explains model predictions by attributing feature contributions using Shapley values.
# - **`Keras-Preprocessing`**: Offers utilities for preprocessing data, including image and text transformations.

# %%
from IPython.display import clear_output

# !sudo apt-get update && apt-get install libgl1 -y
# !pip install openpyxl -q
# !pip install albumentations sweetviz grad-cam lime pandas_profiling shap Keras-Preprocessing -q

clear_output()

# %%
# Standard Libraries
import os
import math
import shutil
import warnings
from typing import Dict, Optional

# Data Handling
import pandas as pd
import numpy as np
import cv2
from PIL import Image

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cm as cm
from matplotlib.colors import LinearSegmentedColormap

# Skimage
from skimage.segmentation import slic, mark_boundaries

# TensorFlow and Keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import Input, Dense, BatchNormalization, Flatten, Conv2D, MaxPooling2D, Dropout, GlobalAveragePooling2D, LeakyReLU
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.applications import ResNet50V2, ResNet101V2, InceptionV3, InceptionResNetV2, MobileNetV2, DenseNet169, NASNetMobile, EfficientNetB7, ConvNeXtBase
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger, LearningRateScheduler

# Keras (Standalone)
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from keras.optimizers import Adam, SGD, Adagrad, Adadelta, RMSprop, Nadam
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint, History, ReduceLROnPlateau, CSVLogger, LearningRateScheduler

# Machine Learning
from sklearn.model_selection import train_test_split, KFold, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (accuracy_score, precision_score, recall_score, classification_report,
                             confusion_matrix, roc_curve, roc_auc_score, matthews_corrcoef, hamming_loss, f1_score, precision_recall_curve)

# Lime and Shap
from lime import lime_image
import shap

# PyTorch Grad-CAM
from pytorch_grad_cam import GradCAM

# Sweetviz (for EDA)
import sweetviz

# IPython for display
from IPython.display import Image, display

# Magic commands (for Jupyter Notebooks)
# %matplotlib inline
# %load_ext tensorboard
# %reload_ext tensorboard

# %% [markdown]
# ### Data Loading and Cleaning
#
# Load class labels from an Excel file, binary test labels from a CSV, clean the class labels DataFrame by removing empty rows and columns, and display the cleaned data.

# %%
la1=pd.read_excel('/workspace/anushka saini/train_val/class_label.xlsx')
la1
# Out:
#            imagePath  Healthy
# 0     100image13.jpg        1
# 1      100image2.jpg        1
# 2     100image65.jpg        0
# 3     100image71.jpg        0
# 4     100image83.jpg        0
# ...              ...      ...
# 3195       pco_4.jpg        1
# 3196       pco_5.jpg        0
# 3197       pco_6.jpg        0
# 3198       pco_7.jpg        0
# 3199       pco_8.jpg        0
#
# [3200 rows x 2 columns]

# %%
la2 = pd.read_csv('/workspace/anushka saini/test/test_label_binary.csv')
la2
# Out:
#            imagePath  Healthy
# 0     image10000.jpg        1
# 1     image10001.jpg        0
# 2     image10002.jpg        1
# 3     image10003.jpg        0
# 4     image10004.jpg        0
# ...              ...      ...
# 1463  image11463.jpg        0
# 1464  image11464.jpg        0
# 1465  image11465.jpg        0
# 1466  image11466.jpg        1
# 1467  image11467.jpg        0
#
# [1468 rows x 2 columns]

# %%
df = la1.dropna(how='all').dropna(how='all', axis=1)
print(df)
# Out:
#            imagePath  Healthy
# 0     100image13.jpg        1
# 1      100image2.jpg        1
# 2     100image65.jpg        0
# 3     100image71.jpg        0
# 4     100image83.jpg        0
# ...              ...      ...
# 3195       pco_4.jpg        1
# 3196       pco_5.jpg        0
# 3197       pco_6.jpg        0
# 3198       pco_7.jpg        0
# 3199       pco_8.jpg        0
#
# [3200 rows x 2 columns]

# %% [markdown]
# ### Train-Validate Split
#
# Split the DataFrame into training and validation sets based on specified percentages, using optional random seed for reproducibility.

# %%
def train_validate_split(df, train_percent=.8, validate_percent=.2, seed=None):
    np.random.seed(seed)
    perm = np.random.permutation(df.index)
    m = len(df.index)
    train_end = int(train_percent * m)
    validate_end = int(validate_percent * m) + train_end
    train = df.iloc[perm[:train_end]]
    validate = df.iloc[perm[train_end:validate_end]]
    # test = df.iloc[perm[validate_end:]]
    return train, validate

# %%
train, validate = train_validate_split(df)
train
# Out:
#           imagePath  Healthy
# 3195      pco_4.jpg        1
# 2932  image3595.jpg        0
# 1377  image0973.jpg        0
# 1364  image0959.jpg        0
# 1468  image1075.jpg        0
# ...             ...      ...
# 2978  image3643.jpg        0
# 3061  image3733.jpg        0
# 1638  image1472.jpg        1
# 1484  image1092.jpg        0
# 3181  normal_40.jpg        1
#
# [2560 rows x 2 columns]

# %%
validate
# Out:
#              imagePath  Healthy
# 3077     image3753.jpg        0
# 2465     image3062.jpg        0
# 355    49image0041.jpg        0
# 892      image0447.jpg        0
# 97    141image0125.jpg        1
# ...                ...      ...
# 938      image0500.jpg        0
# 318       2image50.jpg        0
# 482      90image15.jpg        0
# 715      image0257.jpg        0
# 1687     image1669.jpg        0
#
# [640 rows x 2 columns]

# %% [markdown]
# ### Image and Label Preparation
#
# Map labels, load and preprocess images for training, validation, and testing, and display shapes of image arrays and labels.

# %%
label_mapping = {1: "Healthy", 0: "Unhealthy"}
df['Label'] = df['Healthy'].map(label_mapping)

# %%
train_labels = train[["Healthy"]].values
train_image_paths = [os.path.join('/workspace/anushka saini/train_val/images', filename) for filename in train['imagePath']] #to change when using GPU. similarly for validate and test
train_images = []
for train_image_path in train_image_paths:
    image = load_img(train_image_path, target_size=(300, 300)) # change this when you run on GPU. 320X320 rahegi
    image = img_to_array(image) / 255.0  # Normalize pixel values between 0 and 1
    train_images.append(image)
train_images = np.array(train_images, dtype=np.float32)

# %%
train_images.shape
# Out:
# (2560, 300, 300, 3)

# %%
train_labels.shape
# Out:
# (2560, 1)

# %%
validate_labels = validate[["Healthy"]].values
validate_image_paths = [os.path.join('/workspace/anushka saini/train_val/images', filename) for filename in validate['imagePath']]
validate_images = []
for validate_image_path in validate_image_paths:
    image = load_img(validate_image_path, target_size=(300, 300)) # change this when you run on GPU
    image = img_to_array(image) / 255.0  # Normalize pixel values between 0 and 1
    validate_images.append(image)
validate_images = np.array(validate_images, dtype=np.float32)

# %%
validate_images.shape
# Out:
# (640, 300, 300, 3)

# %%
validate_labels.shape
# Out:
# (640, 1)

# %%
test_labels = la2[["Healthy"]].values
test_image_paths = [os.path.join('/workspace/anushka saini/test/images', filename) for filename in la2['imagePath']]
test_images = []
for test_image_path in test_image_paths:
    image = load_img(test_image_path, target_size=(300, 300)) # change this when you run on GPU
    image = img_to_array(image) / 255.0  # Normalize pixel values between 0 and 1
    test_images.append(image)
test_images = np.array(test_images, dtype=np.float32)

# %%
test_images.shape
# Out:
# (1468, 300, 300, 3)

# %%
test_labels.shape
# Out:
# (1468, 1)

# %% [markdown]
# ### Custom DenseNet169 Model for Binary Classification with Logging
#
# Customizes and compiles a DenseNet169 model for binary classification with training logging.

# %%
base_model=DenseNet169(weights='imagenet', include_top=False,input_shape=(300,300,3))
# Out:
# 2024-01-29 08:24:44.458537: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-29 08:24:44.564423: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38318 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:81:00.0, compute capability: 8.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 [==============================] - 5s 0us/step

# %%
x = base_model.output
x = Flatten()(x)
predictions = Dense(1, activation='sigmoid',
    use_bias=True,
    kernel_initializer="glorot_uniform",
    bias_initializer="zeros",
    kernel_regularizer=None,
    bias_regularizer=None,
    activity_regularizer=None,
    kernel_constraint=None,
    bias_constraint=None,)(x)

model = Model(inputs=base_model.input, outputs=predictions)
for layer in base_model.layers:
    layer.trainable = False
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy', 'binary_accuracy', 'categorical_accuracy', 'top_k_categorical_accuracy', 'Precision', 'Recall'])
csv_logger = CSVLogger("DenseNet169_model_history_log.csv", append=True) #to be changed as per model

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 300, 300, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 306, 306, 3)  0          ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 150, 150, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 150, 150, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 150, 150, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 152, 152, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 75, 75, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 75, 75, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 75, 75, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 75, 75, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 75, 75, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 75, 75, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 75, 75, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 75, 75, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 75, 75, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 75, 75, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 75, 75, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 75, 75, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 75, 75, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 75, 75, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 75, 75, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 75, 75, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 75, 75, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 75, 75, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 75, 75, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 75, 75, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 75, 75, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 75, 75, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 75, 75, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 75, 75, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 75, 75, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 75, 75, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 75, 75, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 75, 75, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 75, 75, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 75, 75, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 75, 75, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 75, 75, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 75, 75, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 75, 75, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 75, 75, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 75, 75, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 75, 75, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 75, 75, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 75, 75, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 75, 75, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 75, 75, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 75, 75, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 75, 75, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 75, 75, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 75, 75, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 75, 75, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 37, 37, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 37, 37, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 37, 37, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 37, 37, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 37, 37, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 37, 37, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 37, 37, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 37, 37, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 37, 37, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 37, 37, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 37, 37, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 37, 37, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 37, 37, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 37, 37, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 37, 37, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 37, 37, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 37, 37, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 37, 37, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 37, 37, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 37, 37, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 37, 37, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 37, 37, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 37, 37, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 37, 37, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 37, 37, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 37, 37, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 37, 37, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 37, 37, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 37, 37, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 37, 37, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 37, 37, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 37, 37, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 37, 37, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 37, 37, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 37, 37, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 37, 37, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 37, 37, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 37, 37, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 37, 37, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 37, 37, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 37, 37, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 37, 37, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 37, 37, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 37, 37, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 37, 37, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 37, 37, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 37, 37, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 37, 37, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 37, 37, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 37, 37, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 37, 37, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 37, 37, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 37, 37, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 37, 37, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 37, 37, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 37, 37, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 37, 37, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 37, 37, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 37, 37, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 37, 37, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 37, 37, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 37, 37, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 37, 37, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 37, 37, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 37, 37, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 37, 37, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 37, 37, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 37, 37, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 37, 37, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 37, 37, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 37, 37, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 37, 37, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 37, 37, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 37, 37, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 37, 37, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 37, 37, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 37, 37, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 37, 37, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 37, 37, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 18, 18, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 18, 18, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 18, 18, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 18, 18, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 18, 18, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 18, 18, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 18, 18, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 18, 18, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 18, 18, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 18, 18, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 18, 18, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 18, 18, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 18, 18, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 18, 18, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 18, 18, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 18, 18, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 18, 18, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 18, 18, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 18, 18, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 18, 18, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 18, 18, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 18, 18, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 18, 18, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 18, 18, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 18, 18, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 18, 18, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 18, 18, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 18, 18, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 18, 18, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 18, 18, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 18, 18, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 18, 18, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 18, 18, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 18, 18, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 18, 18, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 18, 18, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 18, 18, 416)  1664       ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 18, 18, 416)  0          ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 18, 18, 128)  53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 18, 18, 128)  512        ['conv4_block6_1_conv[0][0]']
# ...
#
#  conv5_block25_0_relu (Activati  (None, 9, 9, 1408)  0           ['conv5_block25_0_bn[0][0]']
#  on)
#
#  conv5_block25_1_conv (Conv2D)  (None, 9, 9, 128)    180224      ['conv5_block25_0_relu[0][0]']
#
#  conv5_block25_1_bn (BatchNorma  (None, 9, 9, 128)   512         ['conv5_block25_1_conv[0][0]']
#  lization)
#
#  conv5_block25_1_relu (Activati  (None, 9, 9, 128)   0           ['conv5_block25_1_bn[0][0]']
#  on)
#
#  conv5_block25_2_conv (Conv2D)  (None, 9, 9, 32)     36864       ['conv5_block25_1_relu[0][0]']
#
#  conv5_block25_concat (Concaten  (None, 9, 9, 1440)  0           ['conv5_block24_concat[0][0]',
#  ate)                                                             'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 9, 9, 1440)  5760        ['conv5_block25_concat[0][0]']
#  lization)
#
#  conv5_block26_0_relu (Activati  (None, 9, 9, 1440)  0           ['conv5_block26_0_bn[0][0]']
#  on)
#
#  conv5_block26_1_conv (Conv2D)  (None, 9, 9, 128)    184320      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 9, 9, 128)   512         ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 9, 9, 128)   0           ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 9, 9, 32)     36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 9, 9, 1472)  0           ['conv5_block25_concat[0][0]',
#  ate)                                                             'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 9, 9, 1472)  5888        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 9, 9, 1472)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 9, 9, 128)    188416      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 9, 9, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 9, 9, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 9, 9, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 9, 9, 1504)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 9, 9, 1504)  6016        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 9, 9, 1504)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 9, 9, 128)    192512      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 9, 9, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 9, 9, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 9, 9, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 9, 9, 1536)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 9, 9, 1536)  6144        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 9, 9, 1536)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 9, 9, 128)    196608      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 9, 9, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 9, 9, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 9, 9, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 9, 9, 1568)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 9, 9, 1568)  6272        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 9, 9, 1568)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 9, 9, 128)    200704      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 9, 9, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 9, 9, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 9, 9, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 9, 9, 1600)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 9, 9, 1600)  6400        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 9, 9, 1600)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 9, 9, 128)    204800      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 9, 9, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 9, 9, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 9, 9, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 9, 9, 1632)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 9, 9, 1632)  6528        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 9, 9, 1632)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 9, 9, 128)    208896      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 9, 9, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 9, 9, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 9, 9, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 9, 9, 1664)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 9, 9, 1664)   6656        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 9, 9, 1664)   0           ['bn[0][0]']
#
#  flatten (Flatten)              (None, 134784)       0           ['relu[0][0]']
#
#  dense (Dense)                  (None, 1)            134785      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 12,777,665
# Trainable params: 134,785
# Non-trainable params: 12,642,880
# __________________________________________________________________________________________________

# %% [markdown]
# ### Training, Saving, and Evaluating a DenseNet169 Model
#
# Trains the DenseNet169 model, saves and reloads weights, and evaluates performance on validation and test datasets using classification reports.

# %%
model.fit(train_images,train_labels,validation_data=(validate_images,validate_labels),batch_size=16,
          epochs=250,callbacks=csv_logger,shuffle=False,class_weight=None,steps_per_epoch=None,
          validation_steps=None,
          validation_batch_size=None,
          validation_freq=1,
          max_queue_size=10,
          workers=1,
          use_multiprocessing=False) #make it 250
# Out:
# Epoch 1/250
# 2024-01-29 08:25:47.289300: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8700
# 2024-01-29 08:25:47.418255: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:648] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 160/160 [==============================] - 14s 44ms/step - loss: 2.9538 - accuracy: 0.7063 - binary_accuracy: 0.7063 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.4826 - recall: 0.4773 - val_loss: 2.2733 - val_accuracy: 0.7094 - val_binary_accuracy: 0.7094 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4790 - val_recall: 0.6477
# Epoch 2/250
# 160/160 [==============================] - 4s 27ms/step - loss: 2.0600 - accuracy: 0.7477 - binary_accuracy: 0.7477 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.5563 - recall: 0.5502 - val_loss: 2.7823 - val_accuracy: 0.6641 - val_binary_accuracy: 0.6641 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4325 - val_recall: 0.7102
# Epoch 3/250
# 160/160 [==============================] - 4s 26ms/step - loss: 1.9616 - accuracy: 0.7777 - binary_accuracy: 0.7777 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.6073 - recall: 0.6149 - val_loss: 2.0249 - val_accuracy: 0.7531 - val_binary_accuracy: 0.7531 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5662 - val_recall: 0.4375
# Epoch 4/250
# 160/160 [==============================] - 4s 27ms/step - loss: 1.5835 - accuracy: 0.8012 - binary_accuracy: 0.8012 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.6522 - recall: 0.6424 - val_loss: 2.3885 - val_accuracy: 0.7375 - val_binary_accuracy: 0.7375 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5317 - val_recall: 0.3807
# Epoch 5/250
# 160/160 [==============================] - 4s 27ms/step - loss: 1.4905 - accuracy: 0.8211 - binary_accuracy: 0.8211 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.6830 - recall: 0.6905 - val_loss: 2.2906 - val_accuracy: 0.7688 - val_binary_accuracy: 0.7688 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.6458 - val_recall: 0.3523
# Epoch 6/250
# 160/160 [==============================] - 4s 27ms/step - loss: 1.2503 - accuracy: 0.8359 - binary_accuracy: 0.8359 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.7147 - recall: 0.7029 - val_loss: 2.2567 - val_accuracy: 0.7437 - val_binary_accuracy: 0.7437 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5435 - val_recall: 0.4261
# Epoch 7/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.7864 - accuracy: 0.8684 - binary_accuracy: 0.8684 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.7731 - recall: 0.7593 - val_loss: 2.4511 - val_accuracy: 0.7516 - val_binary_accuracy: 0.7516 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5649 - val_recall: 0.4205
# Epoch 8/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.9755 - accuracy: 0.8574 - binary_accuracy: 0.8574 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.7542 - recall: 0.7387 - val_loss: 3.3394 - val_accuracy: 0.7578 - val_binary_accuracy: 0.7578 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.6129 - val_recall: 0.3239
# Epoch 9/250
# 160/160 [==============================] - 4s 28ms/step - loss: 0.8800 - accuracy: 0.8711 - binary_accuracy: 0.8711 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.7746 - recall: 0.7703 - val_loss: 2.6111 - val_accuracy: 0.7156 - val_binary_accuracy: 0.7156 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4800 - val_recall: 0.4091
# Epoch 10/250
# 160/160 [==============================] - 4s 26ms/step - loss: 1.4244 - accuracy: 0.8418 - binary_accuracy: 0.8418 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.7205 - recall: 0.7235 - val_loss: 3.9774 - val_accuracy: 0.7656 - val_binary_accuracy: 0.7656 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.6383 - val_recall: 0.3409
# Epoch 11/250
# 160/160 [==============================] - 4s 27ms/step - loss: 1.0385 - accuracy: 0.8625 - binary_accuracy: 0.8625 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.7586 - recall: 0.7565 - val_loss: 3.8095 - val_accuracy: 0.7703 - val_binary_accuracy: 0.7703 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.6629 - val_recall: 0.3352
# Epoch 12/250
# 160/160 [==============================] - 4s 26ms/step - loss: 1.
- categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.8960 - recall: 0.9010 - val_loss: 6.8189 - val_accuracy: 0.7250 - val_binary_accuracy: 0.7250 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5000 - val_recall: 0.6250
# Epoch 51/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.5837 - accuracy: 0.9449 - binary_accuracy: 0.9449 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9047 - recall: 0.9010 - val_loss: 6.8901 - val_accuracy: 0.6969 - val_binary_accuracy: 0.6969 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4595 - val_recall: 0.5795
# Epoch 52/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.5571 - accuracy: 0.9508 - binary_accuracy: 0.9508 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9100 - recall: 0.9175 - val_loss: 6.9690 - val_accuracy: 0.7266 - val_binary_accuracy: 0.7266 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5028 - val_recall: 0.5057
# Epoch 53/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.6546 - accuracy: 0.9438 - binary_accuracy: 0.9438 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9021 - recall: 0.8996 - val_loss: 7.2039 - val_accuracy: 0.6953 - val_binary_accuracy: 0.6953 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4566 - val_recall: 0.5682
# Epoch 54/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.5585 - accuracy: 0.9500 - binary_accuracy: 0.9500 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9120 - recall: 0.9120 - val_loss: 7.9010 - val_accuracy: 0.6922 - val_binary_accuracy: 0.6922 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4578 - val_recall: 0.6477
# Epoch 55/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.6352 - accuracy: 0.9398 - binary_accuracy: 0.9398 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.8930 - recall: 0.8955 - val_loss: 7.6284 - val_accuracy: 0.7297 - val_binary_accuracy: 0.7297 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5096 - val_recall: 0.4545
# Epoch 56/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.8433 - accuracy: 0.9312 - binary_accuracy: 0.9312 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.8790 - recall: 0.8790 - val_loss: 8.1650 - val_accuracy: 0.7141 - val_binary_accuracy: 0.7141 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4850 - val_recall: 0.6420
# Epoch 57/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.8583 - accuracy: 0.9336 - binary_accuracy: 0.9336 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.8810 - recall: 0.8858 - val_loss: 8.2670 - val_accuracy: 0.7047 - val_binary_accuracy: 0.7047 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4749 - val_recall: 0.6989
# Epoch 58/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.7931 - accuracy: 0.9320 - binary_accuracy: 0.9320 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.8803 - recall: 0.8803 - val_loss: 8.8919 - val_accuracy: 0.6875 - val_binary_accuracy: 0.6875 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4556 - val_recall: 0.6989
# Epoch 59/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.7955 - accuracy: 0.9336 - binary_accuracy: 0.9336 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.8841 - recall: 0.8817 - val_loss: 9.0600 - val_accuracy: 0.6797 - val_binary_accuracy: 0.6797 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4461 - val_recall: 0.6818
# Epoch 60/250
# 160/160 [==============================] - 4s 26ms/step - loss: 1.0941 - accuracy: 0.9289 - binary_accuracy: 0.9289 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.8748 - recall: 0.8748 - val_loss: 8.2007 - val_accuracy: 0.6891 - val_binary_accuracy: 0.6891 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4506 - val_recall: 0.5966
# Epoch 61/250
# 160/160 [==============================] - 4s 27ms/step - loss: 1.7102 - accuracy: 0.9121 - binary_accuracy: 0.9121 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.8467 - recall: 0.8432 - val_loss: 10.1428 - val_accuracy: 0.6969 - val_binary_accuracy: 0.6969 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4683 - val_recall: 0.7557
# Epoch 62/250
# 160/160 [==============================] - 4s 26ms/step - loss: 2.0701 - accuracy: 0.8988 - binary_accuracy: 0.8988 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.8197 - recall: 0.8253 - val_loss: 7.8253 - val_accuracy: 0.7266 - val_binary_accuracy: 0.7266 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5029 - val_recall: 0.4943
# Epoch 63/250
# 160/160 [==============================] - 4s 26ms/step - loss: 1.9215 - accuracy: 0.9035 - binary_accuracy: 0.9035 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.
250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.8955 - accuracy: 0.9430 - binary_accuracy: 0.9430 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9007 - recall: 0.8982 - val_loss: 12.6125 - val_accuracy: 0.6953 - val_binary_accuracy: 0.6953 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4652 - val_recall: 0.7216
# Epoch 90/250
# 160/160 [==============================] - 4s 26ms/step - loss: 1.0527 - accuracy: 0.9363 - binary_accuracy: 0.9363 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.8895 - recall: 0.8858 - val_loss: 15.7299 - val_accuracy: 0.6672 - val_binary_accuracy: 0.6672 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4416 - val_recall: 0.7955
# Epoch 91/250
# 160/160 [==============================] - 4s 26ms/step - loss: 1.0444 - accuracy: 0.9391 - binary_accuracy: 0.9391 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.8938 - recall: 0.8913 - val_loss: 18.9187 - val_accuracy: 0.6484 - val_binary_accuracy: 0.6484 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4302 - val_recall: 0.8580
# Epoch 92/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.9607 - accuracy: 0.9461 - binary_accuracy: 0.9461 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9096 - recall: 0.8996 - val_loss: 23.0812 - val_accuracy: 0.6359 - val_binary_accuracy: 0.6359 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4260 - val_recall: 0.9318
# Epoch 93/250
# 160/160 [==============================] - 4s 26ms/step - loss: 1.0177 - accuracy: 0.9434 - binary_accuracy: 0.9434 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9008 - recall: 0.8996 - val_loss: 23.5378 - val_accuracy: 0.6281 - val_binary_accuracy: 0.6281 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4213 - val_recall: 0.9432
# Epoch 94/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.9081 - accuracy: 0.9457 - binary_accuracy: 0.9457 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9061 - recall: 0.9023 - val_loss: 24.0188 - val_accuracy: 0.6219 - val_binary_accuracy: 0.6219 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4167 - val_recall: 0.9375
# Epoch 95/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.9034 - accuracy: 0.9500 - binary_accuracy: 0.9500 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9131 - recall: 0.9106 - val_loss: 22.7295 - val_accuracy: 0.6250 - val_binary_accuracy: 0.6250 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4175 - val_recall: 0.9205
# Epoch 96/250
# 160/160 [==============================] - 4s 26ms/step - loss: 1.0859 - accuracy: 0.9469 - binary_accuracy: 0.9469 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9076 - recall: 0.9051 - val_loss: 19.0212 - val_accuracy: 0.6531 - val_binary_accuracy: 0.6531 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4365 - val_recall: 0.8977
# Epoch 97/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.8963 - accuracy: 0.9523 - binary_accuracy: 0.9523 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9150 - recall: 0.9175 - val_loss: 17.8896 - val_accuracy: 0.6562 - val_binary_accuracy: 0.6562 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4371 - val_recall: 0.8693
# Epoch 98/250
# 160/160 [==============================] - 4s 27ms/step - loss: 1.0356 - accuracy: 0.9402 - binary_accuracy: 0.9402 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.8942 - recall: 0.8955 - val_loss: 15.8657 - val_accuracy: 0.6641 - val_binary_accuracy: 0.6641 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4393 - val_recall: 0.8011
# Epoch 99/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.8855 - accuracy: 0.9477 - binary_accuracy: 0.9477 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9078 - recall: 0.9078 - val_loss: 16.0014 - val_accuracy: 0.6484 - val_binary_accuracy: 0.6484 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4232 - val_recall: 0.7670
# Epoch 100/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.8834 - accuracy: 0.9461 - binary_accuracy: 0.9461 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9085 - recall: 0.9010 - val_loss: 13.8035 - val_accuracy: 0.6719 - val_binary_accuracy: 0.6719 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4422 - val_recall: 0.7386
# Epoch 101/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.8820 - accuracy: 0.9445 - binary_accuracy: 0.9445 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9034 - recall: 0.9010 - val_loss: 15.5845 - val_accuracy: 0.6625 - val_binary_accuracy: 0.6625 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4346 - val_recall: 0.7557
# Epoch 102/250
# 160/160 [==============================] - 4s 25ms/step - loss: 1.1971 - accuracy: 0.9387 - binary_accuracy: 0.9387 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.8915 - recall: 0.8927 - val_loss: 13.6271 - val_accuracy: 0.6672 - val_binary_accuracy: 0.6672 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4337 - val_recall: 0.6875
# Epoch 103/250
# 160/160 [==============================] - 4s 26ms/step - loss: 1.3857 - accuracy: 0.9324 - binary_accuracy: 0.9324 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.8826 - recall: 0.8790 - val_loss: 12.7866 - val_accuracy: 0.6859 - val_binary_accuracy: 0.6859 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4525 - val_recall: 0.6761
# Epoch 104/250
# 160/160 [==============================] - 4s 26ms/step - loss: 1.2715 - accuracy: 0.9352 - binary_accuracy: 0.9352 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.8880 - recall: 0.8831 - val_loss: 12.9394 - val_accuracy: 0.6828 - val_binary_accuracy: 0.6828 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4449 - val_recall: 0.6193
# Epoch 105/250
# 160/160 [==============================] - 4s 26ms/step - loss: 1.4750 - accuracy: 0.9297 - binary_accuracy: 0.9297 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.8762 - recall: 0.8762 - val_loss: 13.0613 - val_accuracy: 0.6672 - val_binary_accuracy: 0.6672 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4251 - val_recall: 0.5966
# Epoch 106/250
# 160/160 [==============================] - 4s 26ms/step - loss: 1.4034 - accuracy: 0.9270 - binary_accuracy: 0.9270 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.8719 - recall: 0.8707 - val_loss: 12.3272 - val_accuracy: 0.7125 - val_binary_accuracy: 0.7125 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4808 - val_recall: 0.5682
# Epoch 107/250
# 160/160 [==============================] - 4s 26ms/step - loss: 1.4105 - accuracy: 0.9273 - binary_accuracy: 0.9273 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.8711 - recall: 0.8735 - val_loss: 11.9891 - val_accuracy: 0.7297 - val_binary_accuracy: 0.7297 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5083 - val_recall: 0.5227
# Epoch 108/250
# 160/160 [==============================] - 4s 26ms/step - loss: 1.1327 - accuracy: 0.9434 - binary_accuracy: 0.9434 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9019 - recall: 0.8982 - val_loss: 12.1585 - val_accuracy: 0.7156 - val_binary_accuracy: 0.7156 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4862 - val_recall: 0.6023
# Epoch 109/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.8598 - accuracy: 0.9457 - binary_accuracy: 0.9457 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9050 - recall: 0.9037 - val_loss: 11.8051 - val_accuracy: 0.7266 - val_binary_accuracy: 0.7266 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5026 - val_recall: 0.5511
# Epoch 110/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.7746 - accuracy: 0.9516 - binary_accuracy: 0.9516 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9159 - recall: 0.9133 - val_loss: 12.2032 - val_accuracy: 0.7172 - val_binary_accuracy: 0.7172 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4874 - val_recall: 0.5511
# Epoch 111/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.7460 - accuracy: 0.9516 - binary_accuracy: 0.9516 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9170 - recall: 0.9120 - val_loss: 12.0462 - val_accuracy: 0.7188 - val_binary_accuracy: 0.7188 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.4898 - val_recall: 0.5455
# Epoch 112/250
# ...
# Epoch 214/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.5271 - accuracy: 0.9793 - binary_accuracy: 0.9793 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9629 - recall: 0.9642 - val_loss: 18.0155 - val_accuracy: 0.7547 - val_binary_accuracy: 0.7547 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5941 - val_recall: 0.3409
# Epoch 215/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.6102 - accuracy: 0.9754 - binary_accuracy: 0.9754 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9573 - recall: 0.9560 - val_loss: 18.5954 - val_accuracy: 0.7531 - val_binary_accuracy: 0.7531 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5865 - val_recall: 0.3466
# Epoch 216/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.4634 - accuracy: 0.9809 - binary_accuracy: 0.9809 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9657 - recall: 0.9670 - val_loss: 18.1327 - val_accuracy: 0.7609 - val_binary_accuracy: 0.7609 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.6186 - val_recall: 0.3409
# Epoch 217/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.5613 - accuracy: 0.9777 - binary_accuracy: 0.9777 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9627 - recall: 0.9587 - val_loss: 17.7584 - val_accuracy: 0.7531 - val_binary_accuracy: 0.7531 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5882 - val_recall: 0.3409
# Epoch 218/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.6013 - accuracy: 0.9777 - binary_accuracy: 0.9777 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9602 - recall: 0.9615 - val_loss: 16.2000 - val_accuracy: 0.7422 - val_binary_accuracy: 0.7422 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5433 - val_recall: 0.3920
# Epoch 219/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.5317 - accuracy: 0.9793 - binary_accuracy: 0.9793 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9629 - recall: 0.9642 - val_loss: 21.9478 - val_accuracy: 0.7641 - val_binary_accuracy: 0.7641 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.6667 - val_recall: 0.2841
# Epoch 220/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.7031 - accuracy: 0.9738 - binary_accuracy: 0.9738 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9533 - recall: 0.9546 - val_loss: 19.5742 - val_accuracy: 0.7625 - val_binary_accuracy: 0.7625 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.6364 - val_recall: 0.3182
# Epoch 221/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.5387 - accuracy: 0.9801 - binary_accuracy: 0.9801 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9656 - recall: 0.9642 - val_loss: 22.5106 - val_accuracy: 0.7750 - val_binary_accuracy: 0.7750 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.7162 - val_recall: 0.3011
# Epoch 222/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.6936 - accuracy: 0.9758 - binary_accuracy: 0.9758 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9561 - recall: 0.9587 - val_loss: 18.9341 - val_accuracy: 0.7547 - val_binary_accuracy: 0.7547 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.6000 - val_recall: 0.3239
# Epoch 223/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.6914 - accuracy: 0.9770 - binary_accuracy: 0.9770 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9601 - recall: 0.9587 - val_loss: 18.3933 - val_accuracy: 0.7469 - val_binary_accuracy: 0.7469 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5673 - val_recall: 0.3352
# Epoch 224/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.6317 - accuracy: 0.9781 - binary_accuracy: 0.9781 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9615 - recall: 0.9615 - val_loss: 16.1429 - val_accuracy: 0.7391 - val_binary_accuracy: 0.7391 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5324 - val_recall: 0.4205
# Epoch 225/250
# 160/160 [==============================] - 4s 28ms/step - loss: 0.5170 - accuracy: 0.9773 - binary_accuracy: 0.9773 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9601 - recall: 0.9601 - val_loss: 21.6972 - val_accuracy: 0.7625 - val_binary_accuracy: 0.7625 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.6579 - val_recall: 0.2841
# Epoch 226/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.6801 - accuracy: 0.9773 - binary_accuracy: 0.9773 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9601 - recall: 0.9601 - val_loss: 16.8843 - val_accuracy: 0.7453 - val_binary_accuracy: 0.7453 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5556 - val_recall: 0.3693
# Epoch 227/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.4654 - accuracy: 0.9828 - binary_accuracy: 0.9828 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9672 - recall: 0.9725 - val_loss: 22.6009 - val_accuracy: 0.7672 - val_binary_accuracy: 0.7672 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.6753 - val_recall: 0.2955
# Epoch 228/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.6856 - accuracy: 0.9770 - binary_accuracy: 0.9770 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9601 - recall: 0.9587 - val_loss: 19.0863 - val_accuracy: 0.7469 - val_binary_accuracy: 0.7469 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5673 - val_recall: 0.3352
# Epoch 229/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.7574 - accuracy: 0.9711 - binary_accuracy: 0.9711 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9491 - recall: 0.9491 - val_loss: 19.1324 - val_accuracy: 0.7547 - val_binary_accuracy: 0.7547 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.6067 - val_recall: 0.3068
# Epoch 230/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.6884 - accuracy: 0.9754 - binary_accuracy: 0.9754 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9560 - recall: 0.9574 - val_loss: 24.0672 - val_accuracy: 0.7516 - val_binary_accuracy: 0.7516 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.6197 - val_recall: 0.2500
# Epoch 231/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.5154 - accuracy: 0.9781 - binary_accuracy: 0.9781 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9640 - recall: 0.9587 - val_loss: 20.9775 - val_accuracy: 0.7672 - val_binary_accuracy: 0.7672 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.6392 - val_recall: 0.3523
# Epoch 232/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.4829 - accuracy: 0.9812 - binary_accuracy: 0.9812 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9683 - recall: 0.9656 - val_loss: 16.5761 - val_accuracy: 0.7422 - val_binary_accuracy: 0.7422 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5364 - val_recall: 0.4602
# Epoch 233/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.4395 - accuracy: 0.9793 - binary_accuracy: 0.9793 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9616 - recall: 0.9656 - val_loss: 19.2397 - val_accuracy: 0.7625 - val_binary_accuracy: 0.7625 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.6224 - val_recall: 0.3466
# Epoch 234/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.6633 - accuracy: 0.9777 - binary_accuracy: 0.9777 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9614 - recall: 0.9601 - val_loss: 18.5002 - val_accuracy: 0.7594 - val_binary_accuracy: 0.7594 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.6100 - val_recall: 0.3466
# Epoch 235/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.6401 - accuracy: 0.9758 - binary_accuracy: 0.9758 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9586 - recall: 0.9560 - val_loss: 18.7760 - val_accuracy: 0.7563 - val_binary_accuracy: 0.7563 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5877 - val_recall: 0.3807
# Epoch 236/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.4710 - accuracy: 0.9832 - binary_accuracy: 0.9832 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9698 - recall: 0.9711 - val_loss: 16.3746 - val_accuracy: 0.7453 - val_binary_accuracy: 0.7453 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5481 - val_recall: 0.4205
# Epoch 237/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.4279 - accuracy: 0.9805 - binary_accuracy: 0.9805 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9669 - recall: 0.9642 - val_loss: 15.0543 - val_accuracy: 0.7406 - val_binary_accuracy: 0.7406 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5272 - val_recall: 0.5511
# Epoch 238/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.4463 - accuracy: 0.9812 - binary_accuracy: 0.9812 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9657 - recall: 0.9684 - val_loss: 15.4618 - val_accuracy: 0.7344 - val_binary_accuracy: 0.7344 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5181 - val_recall: 0.4886
# Epoch 239/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.5400 - accuracy: 0.9816 - binary_accuracy: 0.9816 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9670 - recall: 0.9684 - val_loss: 17.3738 - val_accuracy: 0.7531 - val_binary_accuracy: 0.7531 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5833 - val_recall: 0.3580
# Epoch 240/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.6099 - accuracy: 0.9734 - binary_accuracy: 0.9734 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9545 - recall: 0.9519 - val_loss: 18.6096 - val_accuracy: 0.7578 - val_binary_accuracy: 0.7578 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5981 - val_recall: 0.3636
# Epoch 241/250
# 160/160 [==============================] - 4s 27ms/step - loss: 0.6862 - accuracy: 0.9727 - binary_accuracy: 0.9727 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9519 - recall: 0.9519 - val_loss: 15.7182 - val_accuracy: 0.7359 - val_binary_accuracy: 0.7359 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5220 - val_recall: 0.4716
# Epoch 242/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.4681 - accuracy: 0.9805 - binary_accuracy: 0.9805 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9656 - recall: 0.9656 - val_loss: 17.6688 - val_accuracy: 0.7500 - val_binary_accuracy: 0.7500 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5690 - val_recall: 0.3750
# Epoch 243/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.6013 - accuracy: 0.9762 - binary_accuracy: 0.9762 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9574 - recall: 0.9587 - val_loss: 16.9421 - val_accuracy: 0.7500 - val_binary_accuracy: 0.7500 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5702 - val_recall: 0.3693
# Epoch 244/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.4773 - accuracy: 0.9785 - binary_accuracy: 0.9785 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9628 - recall: 0.9615 - val_loss: 20.0017 - val_accuracy: 0.7563 - val_binary_accuracy: 0.7563 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.6000 - val_recall: 0.3409
# Epoch 245/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.5685 - accuracy: 0.9824 - binary_accuracy: 0.9824 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9697 - recall: 0.9684 - val_loss: 17.0965 - val_accuracy: 0.7344 - val_binary_accuracy: 0.7344 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5224 - val_recall: 0.3977
# Epoch 246/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.5695 - accuracy: 0.9824 - binary_accuracy: 0.9824 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9697 - recall: 0.9684 - val_loss: 17.3852 - val_accuracy: 0.7578 - val_binary_accuracy: 0.7578 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5897 - val_recall: 0.3920
# Epoch 247/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.5090 - accuracy: 0.9832 - binary_accuracy: 0.9832 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9711 - recall: 0.9697 - val_loss: 15.9443 - val_accuracy: 0.7375 - val_binary_accuracy: 0.7375 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5267 - val_recall: 0.4489
# Epoch 248/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.5371 - accuracy: 0.9789 - binary_accuracy: 0.9789 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9629 - recall: 0.9629 - val_loss: 18.6913 - val_accuracy: 0.7469 - val_binary_accuracy: 0.7469 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5625 - val_recall: 0.3580
# Epoch 249/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.5045 - accuracy: 0.9805 - binary_accuracy: 0.9805 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9669 - recall: 0.9642 - val_loss: 19.4106 - val_accuracy: 0.7547 - val_binary_accuracy: 0.7547 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.5905 - val_recall: 0.3523
# Epoch 250/250
# 160/160 [==============================] - 4s 26ms/step - loss: 0.5165 - accuracy: 0.9801 - binary_accuracy: 0.9801 - categorical_accuracy: 1.0000 - top_k_categorical_accuracy: 1.0000 - precision: 0.9630 - recall: 0.9670 - val_loss: 19.5198 - val_accuracy: 0.7656 - val_binary_accuracy: 0.7656 - val_categorical_accuracy: 1.0000 - val_top_k_categorical_accuracy: 1.0000 - val_precision: 0.6354 - val_recall: 0.3466

# %%
model.save_weights('DenseNet169_weights.h5')
model.save('DenseNet169_model.h5')
model.load_weights('DenseNet169_weights.h5')

# %%
validate_labels_pred = model.predict(validate_images)

# Apply threshold for binary classification
threshold = 0.5
validate_labels_pred_binary = (validate_labels_pred > threshold).astype(int)

# Extract binary labels
validate_labels = validate[["Healthy"]].values

# Generate classification report
print(classification_report(validate_labels, validate_labels_pred_binary))
# Out:
# 20/20 [==============================] - 224s 11s/step
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       460
#            1       0.92      0.66      0.77       180
#
#     accuracy                           0.89       640
#    macro avg       0.90      0.82      0.85       640
# weighted avg       0.89      0.89      0.88       640

# %%
test_labels_pred = model.predict(test_images)

# Apply threshold for binary classification
threshold = 0.5
test_labels_pred_binary = (test_labels_pred > threshold).astype(int)

# Extract binary labels
test_labels = la2[["Healthy"]].values

# Generate classification report
print(classification_report(test_labels, test_labels_pred_binary))
# Out:
# 46/46 [==============================] - 501s 11s/step
#               precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90      1051
#            1       0.87      0.57      0.69       417
#
#     accuracy                           0.85      1468
#    macro avg       0.86      0.77      0.80      1468
# weighted avg       0.85      0.85      0.84      1468
